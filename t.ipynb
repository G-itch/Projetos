# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.style.use("seaborn")

# %%
df = pd.DataFrame()
cont = 1
def gráfico(x):
    global df,cont,y
    if cont == 1:
        y = pd.Series([x],index=[cont])
    if cont > 1:
         z = pd.Series([x],index=[cont]) 
         y = pd.concat([y,z],axis=0)
         y.plot.line()
    cont +=1 
    return y

# %%
import random 
for i in range(0,100):
    gráfico(random.randint(0,100))

# %%
random.randint(0,100)
# Out:
# 20

# %%
cont
# Out:
# 2

# %%
pd.DataFrame([1,2])
# Out:
#    0
# 0  1
# 1  2

# %%
# Out:
# 2    1
# dtype: int64
