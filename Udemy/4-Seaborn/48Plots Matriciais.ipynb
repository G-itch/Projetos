# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
flights= sns.load_dataset("flights")
tips = sns.load_dataset("tips")

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
crr = tips.corr()

# %%
sns.heatmap(crr, cmap="Blues",annot=True)

# %%
fpt = flights.pivot_table(values="passengers",index="month",columns="year")

# %%
plt.figure(figsize=(8,6),dpi=200)
f = sns.heatmap(fpt,annot=True,fmt="d",annot_kws={"size":8,"color":"white"})

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,6))
sns.clustermap(fpt,annot=True,annot_kws={"size":12},fmt="d")
