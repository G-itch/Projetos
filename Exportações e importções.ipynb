# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel("Exportações_APEC_2019.xlsx")

# %%
df.columns=["Exportações","Porcentagem"]

# %%
df.plot()

# %%
plt.figure(figsize=[25,10])
x = sns.barplot(df["Exportações"],df["Porcentagem"],palette="magma")
x.set_title("Principais exportações dos países da APEC 2018",fontsize=20)
x.set_xlabel("Exportações",fontsize=15)
x.set_ylabel("Porcentagem",fontsize=15)
# Out:
# Text(0, 0.5, 'Porcentagem')

# %%
import seaborn as sns

# %%
df
# Out:
#                                          Exportações  Porcentagem
# 6  Peças e acessórios\n(excluindo capas) \npara c...          1.2
# 7                                               Ouro          1.6
# 8      Peças e acessórios \npara motores de veículos          2.1
# 9                             Oléo de petróleo bruto          2.4
# 1              Automação de \nprocessamento de dados          3.0
# 0                                Motores de veículos          3.4
# 2       Oléos de petróleo\n(excluindo o  óleo bruto)          3.4
# 3                               Outras \nmercadorias          3.8
# 4  Fornecimento elétrico\npara linha de telefonia...          5.1
# 5  Circuitos eletrônicos\nintegrados e micromonta...          6.5

# %%
plt.bar(df["Importações"],df["Porcentagem"])
# Out:
# <BarContainer object of 10 artists>

# %%
df.sort_values(by=["Porcentagem"],ascending=True,inplace=True)

# %%
df2 = pd.read_excel("Importações_APEC_2019.xlsx")

# %%
df2.columns=["Importações","Porcentagem"]

# %%
df2.sort_values(by="Porcentagem",inplace = True)

# %%
plt.figure(figsize=[25,10])
g=sns.barplot(df2["Importações"],df2["Porcentagem"],palette="cool")
g.set_title("Principais importações dos países da APEC 2018",fontsize=20)
g.set_xlabel("Importações",fontsize=15)
g.set_ylabel("Porcentagem",fontsize=15)
# Out:
# Text(0, 0.5, 'Porcentagem')
